# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data and labels

# %%
# %%timeit
training_data = pd.read_parquet(r"../datasets/BTCUSDT/")
labels = pd.read_parquet(r"../datasets/LABEL_BTCUSDT/")
# Out:
# 177 ms ± 34.5 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
training_data = pd.read_parquet(r"../datasets/BTCUSDT/",dtype_backend='pyarrow')
labels = pd.read_parquet(r"../datasets/LABEL_BTCUSDT/",dtype_backend='pyarrow')

# %%
labels.drop(columns="SYMBOL", inplace=True)
# training_data.index = pd.to_datetime(training_data.index, unit="ms")
full_data = training_data.join(labels, how="left")
labels.index = pd.to_datetime(labels.index, unit="ms") + pd.Timedelta(hours=7)

# %%
labels * 54.72 - 19.75
# Out:
#                         LABEL
# OPEN_TIME
# 2017-09-16 17:00:00  1.835128
# 2017-09-16 18:00:00  1.634133
# 2017-09-16 19:00:00  0.002586
# 2017-09-16 20:00:00  2.075343
# 2017-09-16 21:00:00  4.980857
# ...                       ...
# 2023-07-25 19:00:00  2.379553
# 2023-07-25 20:00:00  3.131973
# 2023-07-25 21:00:00  3.133412
# 2023-07-25 22:00:00  2.778810
# 2023-07-25 23:00:00  2.390162
#
# [51197 rows x 1 columns]

# %%
sns.lineplot(labels)
# Out:
# <Axes: xlabel='OPEN_TIME'>
