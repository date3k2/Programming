# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
t = int(input())
for _ in range(t):
    n, k = map(int, input().split())
    a = list(map(int, input().split()))
    for i in a:
        if i == k:
            print("YES")
            break
    else:
        print("NO")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\nguye\Documents\Code\Programming\Python\codeforces-900.ipynb Cell 1 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/nguye/Documents/Code/Programming/Python/codeforces-900.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
#       <a href='vscode-notebook-cell:/c%3A/Users/nguye/Documents/Code/Programming/Python/codeforces-900.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> input = sys.stdin.readline
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nguye/Documents/Code/Programming/Python/codeforces-900.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> t = int(input())
#       <a href='vscode-notebook-cell:/c%3A/Users/nguye/Documents/Code/Programming/Python/codeforces-900.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> for _ in range(t):
#       <a href='vscode-notebook-cell:/c%3A/Users/nguye/Documents/Code/Programming/Python/codeforces-900.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a>     n, k = map(int, input().split())
#
# ValueError: invalid literal for int() with base 10: '3 5'

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
t = int(input())
for _ in range(t):
    n = int(input())
    for i in range(n):
        print(i + 5, end=" ")
    print()

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
t = int(input())
for _ in range(t):
    n, k, x = map(int, input().split())
    if k * (k + 1) // 2 <= x <= (2 * n - k + 1) * k // 2:
        print("YES")
    else:
        print("NO")

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
t = int(input())
for _ in range(t):
    n, k, x = map(int, input().split())
    if k * (k + 1) // 2 <= x <= (2 * n - k + 1) * k // 2:
        print("YES")
    else:
        print("NO")

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
t = int(input())
for _ in range(t):
    n, k = map(int, input().split())
    s = input().rstrip()
    l = list(map(int, input().split()))
    r = list(map(int, input().split()))
    q = int(input())
    query = list(map(int, input().split()))
    # for i in range(q):
    #     print(s[l[i] - 1 : r[i]].count(chr(query[i] + 96)))

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
t = int(input())
for _ in range(t):
    n = int(input())
    a = list(map(int, input().split()))
    q = int(input())

# %%
class Solution:
    def decodeAtIndex(self, s: str, k: int) -> str:
        ans = 0
        cp = []
        st = ""
        for i in s:
            if i.isdigit():
                x = int(i)
                cp.append((ans, st, x))
                ans *= x
                if ans >= k:
                    break
            else:
                ans += 1
                st += i
        else:
            if s[-1].isalpha():
                cp.append((ans, st, 1))
        # x = 0
        # for i in range(len(cp) - 1, -1, -1):
        #     x = k
        #     k %= cp[i][0]
        #     if k == 0 or i == 0 or x < cp[i-1][0]:
        #         if x > cp[i][2] * cp[i][0]:
        #             return cp[i + 1][1][
        #                 len(cp[i][1]) + k - 1 + (x // cp[i][0] - cp[i][2]) * cp[i][0]
        #             ]
        #         else:
        #             return cp[i][1][k - 1]
        return cp


s = "leet2code3bac"
k = 38
print(Solution().decodeAtIndex(s, k))
# Out:
# [(4, 'leet', 2), (12, 'leetcode', 3), (39, 'leetcodebac', 1)]

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
n = int(input())
a = list(map(int, input().split()))
print(sum(a))

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
n = int(input())
for i in range(100, 1000):
    if i % n == 0:
        print(i, end=" ")

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
kwh_tieu_thu = int(input())

gia_moi = (
    (kwh_tieu_thu <= 100) * kwh_tieu_thu * 1.728
    + (100 < kwh_tieu_thu <= 200) * (100 * 1.728 + (kwh_tieu_thu - 100) * 2.074)
    + (200 < kwh_tieu_thu <= 400)
    * (100 * 1.728 + 100 * 2.074 + (kwh_tieu_thu - 200) * 2.612)
    + (400 < kwh_tieu_thu <= 700)
    * (100 * 1.728 + 100 * 2.074 + 200 * 2.612 + (kwh_tieu_thu - 400) * 3.111)
    + (700 < kwh_tieu_thu)
    * (
        100 * 1.728
        + 100 * 2.074
        + 200 * 2.612
        + 300 * 3.111
        + (kwh_tieu_thu - 700) * 3.457
    )
)

gia_cu = (
    (kwh_tieu_thu <= 50) * kwh_tieu_thu * 1.728
    + (50 < kwh_tieu_thu <= 100) * (50 * 1.728 + (kwh_tieu_thu - 50) * 1.786)
    + (100 < kwh_tieu_thu <= 200)
    * (50 * 1.728 + 50 * 1.786 + (kwh_tieu_thu - 100) * 2.074)
    + (200 < kwh_tieu_thu <= 300)
    * (50 * 1.728 + 50 * 1.786 + 100 * 2.074 + (kwh_tieu_thu - 200) * 2.612)
    + (300 < kwh_tieu_thu <= 400)
    * (
        50 * 1.728
        + 50 * 1.786
        + 100 * 2.074
        + 100 * 2.612
        + (kwh_tieu_thu - 300) * 2.919
    )
    + (400 < kwh_tieu_thu)
    * (
        50 * 1.728
        + 50 * 1.786
        + 100 * 2.074
        + 100 * 2.612
        + 100 * 2.919
        + (kwh_tieu_thu - 400) * 3.015
    )
)

chenh_lech = (gia_moi - gia_cu) * 1100

print(f"{chenh_lech:.2f}")

# %%
import sys

input = sys.stdin.readline
try:
    y, m, d = input().rstrip().split("-")
    if len(y) != 4 or len(m) != 2 or len(d) != 2 or int(m) > 12 or int(d) > 31:
        raise Exception
    print(int(y), int(m), int(d))
except:
    print("INCORRECT")

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
n = int(input())
a = list(map(int, input().split()))
odd = 0
for i in a:
    if i % 2:
        odd += 1
print(odd, n - odd)

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
a, b = map(int, input().split())
print(a + b, a - b, a * b, a // b)

# %%
from datetime import datetime
import sys

input = sys.stdin.readline

try:
    s = input().rstrip()
    time_obj = datetime.strptime(s, "%H:%M:%S").time()
    time = time_obj.strftime("%H:%M:%S")
    if time != s:
        raise Exception
    x, y, z = time_obj.hour, time_obj.minute, time_obj.second
    print(x * 3600 + y * 60 + z)
except:
    print("INCORRECT")

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
a, b, c = map(float, input().split())
delta = b**2 - 4 * a * c
if delta < 0:
    print("NO SOLUTION")
elif delta == 0:
    print(f"{-b/(2*a):.2f}")
else:
    print(f"{(-b-delta**0.5)/(2*a):.2f} {(-b+delta**0.5)/(2*a):.2f}")

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
n, k = map(int, input().split())
a = list(map(int, input().split()))
s = sum(a[:k])
count_even = s % 2 == 0
for i in range(k, n):
    s += a[i] - a[i - k]
    count_even += s % 2 == 0
print(count_even)

# %%
import fileinput

count_word = 0
for line in fileinput.input():
    count_word += len(line.split())
print(count_word)

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
p1 = input().rstrip()
p2 = input().rstrip()
t = input().rstrip()
print(t.replace(p1, p2))

# %%
import sys
from typing import List
sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline


class SegmentTree:
    def __init__(self, n: int, a: List[int]):
        """
        Initialize the segment tree with n elements and a list of n elements
        """
        self.n = n
        self.tree = [0] * (4 * n)
        self.a = a

    def build(self, v: int, tl: int, tr: int) -> None:
        """
        Build the segment tree recursively
        """
        if tl == tr:
            self.tree[v] = self.a[tl]
        else:
            tm = (tl + tr) // 2
            self.build(v * 2, tl, tm)
            self.build(v * 2 + 1, tm + 1, tr)
            self.tree[v] = max(self.tree[v * 2], self.tree[v * 2 + 1])

    def query(self, v: int, tl: int, tr: int, l: int, r: int) -> int:
        """
        Query the maximum value in the range [l, r]
        """
        if l > r:
            return -1e9
        if l == tl and r == tr:
            return self.tree[v]
        tm = (tl + tr) // 2
        return max(
            self.query(v * 2, tl, tm, l, min(r, tm)),
            self.query(v * 2 + 1, tm + 1, tr, max(l, tm + 1), r),
        )

    def update(self, v: int, tl: int, tr: int, i: int, new_val: int) -> None:
        """
        Update the value of a[i] to new_val
        """
        if tl == tr:
            self.a[i] = new_val
            self.tree[v] = new_val
        else:
            tm = (tl + tr) // 2
            if i <= tm:
                self.update(v * 2, tl, tm, i, new_val)
            else:
                self.update(v * 2 + 1, tm + 1, tr, i, new_val)
            self.tree[v] = max(self.tree[v * 2], self.tree[v * 2 + 1])


n = int(input())
a = list(map(int, input().split()))
tree = SegmentTree(n, a)
tree.build(1, 0, n - 1)
_ = input()
max_a = max(a)
min_a = min(a)
sum_a = sum(a)
while True:
    query = input().rstrip()
    if query == "find-max":
        print(max_a)
    elif query == "find-min":
        print(min_a)
    elif query == "sum":
        print(sum_a)
    elif query == "***":
        break
    else:
        _, l, r = query.split()
        print(tree.query(1, 0, n - 1, int(l) - 1, int(r) - 1))

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline


def gen_bin_pem(n):
    for i in range(0, 2):
        if n == 1:
            yield str(i)
        else:
            for j in gen_bin_pem(n - 1):
                if i == 1 and j[0] == "1":
                    continue
                yield str(i) + j


n = int(input())
for i in gen_bin_pem(n):
    print(i)

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
t = int(input())
for _ in range(t):
    n, m = map(int, input().split())
    a = list(map(int, input().split()))
    b = list(map(int, input().split()))
    if m == n:
        for i in range(n):
            if a[i] != b[i]:
                print(0)
                break
        else:
            print(1)
    else:
        print(0)

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
n = int(input())
a = list(map(int, input().split()))
print(*sorted(a))

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
n = int(input())
a = list(map(int, input().split()))
w = 0
max_w = -float("inf")
for i in a:
    w += i
    max_w = max(max_w, w)
    if w < 0:
        w = 0
print(max_w)

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
t = int(input())
for _ in range(t):
    n = int(input())
    print(500 // n + 1 if 500 % n else 500 // n)

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
n, m = map(int, input().split())
a = list(map(int, input().split()))
m -= sum(a)
dp = [0] * (m + 1)
dp[0] = 1
for coff in a:
    for i in range(coff, m + 1):
        dp[i] += dp[i - coff]
print(dp[m])

# %%
import sys
from functools import lru_cache


class Solution:
    @lru_cache(None)
    def countSol(self, coeff, start, end, rhs):
        if rhs == 0:
            return 1
        result = 0
        for i in range(start, end + 1):
            if coeff[i] <= rhs:
                result += self.countSol(coeff, i, end, rhs - coeff[i])

        return result


sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
n, m = map(int, input().split())
a = list(map(int, input().split()))
m -= sum(a)
print(Solution().countSol(tuple(a), 0, n - 1, m))

# %%
import sys

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline


def permutation(n):
    if n == 1:
        yield [1]
    else:
        for j in permutation(n - 1):
            for i in range(n, 0, -1):
                yield j[:i-1] + [n] + j[i-1:]

n = int(input())
for i in sorted(permutation(n)):
    print(*i)

# %%
import sys
from itertools import permutations
sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline

n = int(input())
for i in permutations(range(1, n + 1)):
    print(*i)

# %%
import sys
from collections import defaultdict

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
n, L, m = map(int, input().split())
d = defaultdict(bool)
for _ in range(n):
    x = int(input())
    d[x] = True
key = 1
for _ in range(m):
    while d[key]:
        key += 1
    key += 1
ans = [i for i in d]
ans.sort()
for i in ans:
    print(str(i).zfill(L))

# %%
# muộn rồi mà vẫn chưa ngủ được, thôi thì làm bài này cho vui
# đề bài: https://codeforces.com/problemset/problem/1335/C
# here is the solution
import sys
from collections import defaultdict

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline
t = int(input())
for _ in range(t):
    n = int(input())
    a = list(map(int, input().split()))
    d = defaultdict(int)
    for i in a:
        d[i] += 1
    l, r = 0, max(d.values())
    # binary search
    while l < r:
        mid = (l + r + 1) // 2
        if mid <= sum(d[i] // mid for i in d):
            l = mid
        else:
            r = mid - 1

# %%
a = [1,2,5,2,1,0o4,0]
list(filter(None, a))
# Out:
# [1, 2, 5, 2, 1, 4]

# %%
import sys
from collections import defaultdict

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline

n = int(input())
w = list(map(int, input().split()))
adj = defaultdict(list)
for _ in range(n - 1):
    u, v = map(int, input().split())
    adj[u].append(v)
    adj[v].append(u)

stack = [(1, None)]
max_w = [0] * (n + 1)
while stack:
    u, parent = stack.pop()
    for v in adj[u]:
        if v != parent:
            stack.append((v, u))
    max_w[u] = w[u - 1]
    for v in adj[u]:
        if v != parent:
            # choose u or not u and all its children
            pass
# print(max_w)
# sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
# sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
# input = sys.stdin.readline
# n = int(input())
# w = list(map(int, input().split()))
# adj = defaultdict(list)
# for _ in range(n-1):
#     u, v = map(int, input().split())
#     adj[u].append(v)
#     adj[v].append(u)
# def max_w(u):
#     if not adj[u]:
#         return w[u-1]
#     return max(w[u-1], sum(max_w(v) for v in adj[u]))
# print(max_w(1))

# %%
from typing import List
from heapq import heappush, heappop


class Solution:
    def scheduleCourse(self, courses: List[List[int]]) -> int:
        courses.sort(key=lambda x: x[1])
        ans = duration = 0
        biggest = []
        for dur, last in courses:
            if duration + dur <= last:
                ans += 1
                duration += dur
                heappush(biggest, -dur)
            elif biggest and -biggest[0] > dur:
                duration += dur + heappop(biggest)
                heappush(biggest, -dur)
        return ans, courses


courses = [[100, 200], [200, 1300], [1000, 1250], [2000, 3200]]
courses = [[3411, 7142], [602, 8247], [1108, 4342], [7986, 8414], [1696, 8114]]
courses = [[5, 5], [5, 14], [4, 13], [5, 10]]
print(Solution().scheduleCourse(courses))
# Out:
# (3, [[5, 5], [5, 10], [4, 13], [5, 14]])

# %%
# random courses using numpy
import numpy as np
x = np.random.randint(1, 10000, size=(200, 2))
x.sort(axis=1)
x = list(map(list,x))
import pyperclip
pyperclip.copy(str(x))

# %%
from functools import lru_cache

class Solution:
    def numOfArrays(self, n: int, m: int, k: int) -> int:
        @lru_cache(None)
        def count_arrays(index, max_num, remaining_changes):
            if index == n:
                return int(remaining_changes == 0)
            
            ans = (max_num * count_arrays(index + 1, max_num, remaining_changes)) % MOD
            for num in range(max_num + 1, m + 1):
                ans = (ans + count_arrays(index + 1, num, remaining_changes - 1)) % MOD
                
            return ans
        
        MOD = 10 ** 9 + 7
        return count_arrays(0, 0, k)

# %%
from typing import List
from functools import cache


class Solution:
    def maxDotProduct(self, nums1: List[int], nums2: List[int]) -> int:
        @cache
        def solve(i, j):
            if i == len(nums1) or j == len(nums2):
                return 0
            return max(
                nums1[i] * nums2[j] + solve(i + 1, j + 1),
                solve(i + 1, j),
                solve(i, j + 1),
            )

        if max(nums1) < 0 and min(nums2) > 0:
            return max(nums1) * min(nums2)
        if max(nums2) < 0 and min(nums1) > 0:
            return max(nums2) * min(nums1)
        return solve(0, 0)


nums1 = [4, 2, 12]
nums2 = [-5, -2, -1]
print(Solution().maxDotProduct(nums1, nums2))
# Out:
# -2

# %%
import sys
from collections import Counter
from functools import lru_cache

sys.stdin = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.inp", "r")
sys.stdout = open(r"C:\Users\nguye\Documents\Code\Programming\C++\test.out", "w")
input = sys.stdin.readline


class Solution:
    def mins(self, a, d):
        @lru_cache(maxsize=None)
        def solve(begin):
            mins = float("inf")
            if begin == len(a):
                return 0
            for i in range(begin, len(a)):
                mins = min(
                    mins, (d[a[begin - 1]] - 1) * a[i] + a[begin - 1] + solve(i + 1)
                )
            return mins

        return solve(1)


t = int(input())
for _ in range(t):
    s = Solution()
    n = int(input())
    a = list(map(int, input().split()))
    c = Counter(a)
    if c[0] <= 1:
        print(0)
        continue
    mex = 0
    while mex in c:
        mex += 1
    e = sorted(list(set(a)))
    e.append(mex)
    c[mex] = 1
    print(s.mins(e, c))
